# %% [markdown]
# # Loading up all the necessary libraries for the project

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random
import os

random.seed()

# %% [markdown]
# ---

# %% [markdown]
# ## Data common to the next few bar charts

# %%
labels = ['A', 'B', 'C']
values = [1, 4, 2]

# %% [markdown]
# # Bar Charts
#
# The format for the `plt.bar()` function is `plt.bar(x_axis_values, y_axis_values)`
#
# `plt.figure()` must be mentioned before calling the `.bar()` or `.plot()` function

# %%
plt.figure(figsize=(6, 4), dpi=100)  # This must be mentioned before the .bar or .plot function

# plt.bar(values, labels)  # incorrect
plt.bar(labels, values)  # correct

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Data common to the next few bar charts

# %%
labels = ['A', 'B', 'C', 'D']
values = [1, 4, 2, 8]

# %% [markdown]
# ## Adding an overlay over each of the bars

# %%
plt.figure(figsize=(6, 4), dpi=100)  # This must be mentioned before the .bar or .plot function

# plt.bar(values, labels)  # incorrect
bars = plt.bar(labels, values)  # correct
# bars now holds a list of bars in the bar chart

# We now set an overlay design over the first bar
bars[0].set_hatch('/')
bars[1].set_hatch('o')
bars[2].set_hatch('*')
bars[3].set_hatch('\\')

plt.show()

# %% [markdown]
# ## Making it a little cleaner

# %%
plt.figure(figsize=(6, 4), dpi=100)  # This must be mentioned before the .bar or .plot function

# plt.bar(values, labels)  # incorrect
bars = plt.bar(labels, values)  # correct
# bars now holds a list of bars in the bar chart

# We now set an overlay design over the first bar
list_of_hatches = ['/', 'o', '*', '\\']
for ind, bar in enumerate(bars):
    bar.set_hatch(list_of_hatches[ind])

# The type(bars[0]) = matplotlib.patches.Rectangle which is an object hence bar gets only
# a reference to the elements of bars and not a copy and hence the effect of the above for loop works
    

plt.show()

# %%
type(bars[0])
# Out:
# matplotlib.patches.Rectangle
